# %% [markdown]
# # Example 01: MNIST Demo

# %% [markdown]
# ## (i) Import libraries

# %%
import sys
import matplotlib.pyplot as plt
# %matplotlib inline
import visualization

# %% [markdown]
# ## (ii) Plot classification accuracy
# The dotted lines correspond to the epoch number at which the refinement phase started.

# %%
exp_dir = '/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/experiments/cifar10/cifar10/'
models_list = ["debug"]

records_file_list = [exp_dir + model_name + '/checkpoints/records.pkl' for model_name in models_list]
model_files = [exp_dir + model_name + '/checkpoints/model.pth' for model_name in models_list]

print(records_file_list)
print(model_files)

visualization.plot_performance(records_file_list, models_list, ymax = 3.0, figsize=(10,7), finetune_position=True)
visualization.plot_accuracy(records_file_list, models_list, figsize=(10,7), ymin=0, ymax=98, finetune_position=True)
# Out:
# ['/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/experiments/cifar10/cifar10/debug/checkpoints/records.pkl']
# ['/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/experiments/cifar10/cifar10/debug/checkpoints/model.pth']
# debug: test accuracy = 70.91000366210938

# %% [markdown]
# ## (iii) Compute model size

# %%
_ = visualization.compute_number_of_params(model_files, models_list, is_gpu=False)
# Out:
# Model: debug
# Number of parameters summary:
#     Total: 2897546
#     Max per branch: 2897546
#     Min per branch: 2897546
#     Average per branch: 2897546.0

# %% [markdown]
# ## (iv) Visualise the tree structure

# %%
fig_dir = exp_dir + 'run0' + '/figures/'
visualization.visualize_treestructures(fig_dir, figsize=(10,20))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/hongyu/Projects/SubspaceLearningMachine_SoftTree/evaluation_cifar10.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B68.181.2.109/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/evaluation_cifar10.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> fig_dir = exp_dir + 'run0' + '/figures/'
# ----> <a href='vscode-notebook-cell://ssh-remote%2B68.181.2.109/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/evaluation_cifar10.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> visualization.visualize_treestructures(fig_dir, figsize=(10,20))
#
# File ~/Projects/SubspaceLearningMachine_SoftTree/visualization.py:481, in visualize_treestructures(fig_dir, figsize, fig_name)
#     480 def visualize_treestructures(fig_dir, figsize=(5,5), fig_name=''):
# --> 481     figs_list = [f for f in os.listdir(fig_dir)]
#     482     figs_list.sort()
#     484     # load and plot
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/hongyu/Projects/SubspaceLearningMachine_SoftTree/experiments/cifar10/cifar10/run0/figures/'
